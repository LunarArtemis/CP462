# %% [markdown]
# **นายปุณยเกียรติ ถนอมทรัพย์ 64102010080**

# %%
# %matplotlib inline
#sets the backend of matplotlib to the 'inline' backend
import numpy as np
import matplotlib.pyplot as plt
import imageio


x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# Enable this if runtime is terminate
#photo_data = imageio.imread('https://images.ctfassets.net/81iqaqpfd8fy/2A3Xwv1sCseoYUeIiwas22/fd658906812708d7c825547aabdbfd9b/Drugs.jpg?w=1200&h=1200&fm=jpg&fit=fill')

photo_data = imageio.imread('/content/Drugs.jpg')


photo_data2 = photo_data.copy()
photo_data2[800:1200, : ] = 0

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,15))
ax1.imshow(photo_data).set_cmap('hot')
ax1.set_title('Original')
ax1.axis('off')
ax2.imshow(photo_data2).set_cmap('hot')
ax2.set_title('Modified')
ax2.axis('off')
plt.show()
# Out:
# <ipython-input-3-fa69dc70623a>:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   photo_data = imageio.imread('/content/Drugs.jpg')
